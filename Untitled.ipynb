# %%
import pandas as pd
import numpy as np


dataset = pd.read_csv("clinical_events.csv",index_col=0)
dataset.head()
# Out:
# /Users/lno7761/.pyenv/versions/3.9.1/lib/python3.9/site-packages/pandas/compat/__init__.py:97: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
#    clinical_event_id  clinical_event_member_id            clinical_event_name  \
# 1                1.0                         1                   ANNUAL VISIT
# 2                2.0                         1         STROKE HOSPITALIZATION
# 3                3.0                         1  HYPERTENSION MANAGEMENT VISIT
# 4                4.0                         1  HYPERTENSION MANAGEMENT VISIT
# 5                5.0                         2                   ANNUAL VISIT
#
#    clinical_event_time  clinical_event_member_age  member_male
# 1                   41                         81            1
# 2                  641                         81            1
# 3                  116                         81            1
# 4                  293                         81            1
# 5                   14                         76            1

# %% [markdown]
# # Dataset attributes

# %%
print("shape of dataset = ", dataset.shape)
print("number of unique clinical_event_id = ", len(dataset.clinical_event_id.unique()))
print("max clinical_event_id = ", dataset.clinical_event_id.max())
print("number of unique members = ", len(dataset.clinical_event_member_id.unique()))
print("max member id = ", dataset.clinical_event_member_id.max())
# Out:
# shape of dataset =  (511846, 6)
# number of unique clinical_event_id =  511846
# max clinical_event_id =  511846.0
# number of unique members =  200000
# max member id =  200000

# %%
print("gender distribution\n\n",dataset.member_male.value_counts())
print("clinical_event_name distribution\n\n",dataset.clinical_event_name.value_counts())
# Out:
# gender distribution
#
#  1    511846
# Name: member_male, dtype: int64
# clinical_event_name distribution
#
#  ANNUAL VISIT                     200000
# HYPERTENSION MANAGEMENT VISIT    153326
# DIABETES MANAGEMENT VISIT         86840
# HEART FAILURE HOSPITALIZATION     33606
# STROKE HOSPITALIZATION            24821
# ATRIAL FIBRILLATION               13253
# Name: clinical_event_name, dtype: int64

# %% [markdown]
# ### clinical event counts per patient

# %%
clinical_event_counts = pd.DataFrame(dataset.groupby("clinical_event_name").clinical_event_member_id.value_counts().groupby(level=0).value_counts())
clinical_event_counts.columns = ["# patients"]
clinical_event_counts = clinical_event_counts.reset_index()
clinical_event_counts.columns = ["clinical_event_name","counts per patient","# patients"]
clinical_event_counts
# Out:
#               clinical_event_name  counts per patient  # patients
# 0                    ANNUAL VISIT                   1      200000
# 1             ATRIAL FIBRILLATION                   1        4509
# 2             ATRIAL FIBRILLATION                   2        4372
# 3       DIABETES MANAGEMENT VISIT                   2        7957
# 4       DIABETES MANAGEMENT VISIT                   3        7790
# 5       DIABETES MANAGEMENT VISIT                   4        4305
# 6       DIABETES MANAGEMENT VISIT                   1        3853
# 7       DIABETES MANAGEMENT VISIT                   6         911
# 8       DIABETES MANAGEMENT VISIT                   7         873
# 9       DIABETES MANAGEMENT VISIT                   8         854
# 10      DIABETES MANAGEMENT VISIT                   5         839
# 11      DIABETES MANAGEMENT VISIT                   9         431
# 12  HEART FAILURE HOSPITALIZATION                   2        6672
# 13  HEART FAILURE HOSPITALIZATION                   1        5860
# 14  HEART FAILURE HOSPITALIZATION                   3        1519
# 15  HEART FAILURE HOSPITALIZATION                   4        1480
# 16  HEART FAILURE HOSPITALIZATION                   5         785
# 17  HYPERTENSION MANAGEMENT VISIT                   2       11104
# 18  HYPERTENSION MANAGEMENT VISIT                   3       10844
# 19  HYPERTENSION MANAGEMENT VISIT                   4        6711
# 20  HYPERTENSION MANAGEMENT VISIT                   1        5431
# 21  HYPERTENSION MANAGEMENT VISIT                   8        2219
# 22  HYPERTENSION MANAGEMENT VISIT                   7        2204
# 23  HYPERTENSION MANAGEMENT VISIT                   5        2176
# 24  HYPERTENSION MANAGEMENT VISIT                   6        2123
# 25  HYPERTENSION MANAGEMENT VISIT                   9        1057
# 26         STROKE HOSPITALIZATION                   1       24821

# %% [markdown]
# ### number of event per patient

# %%
events_per_patient = pd.DataFrame(dataset.groupby("clinical_event_member_id").clinical_event_id.value_counts().groupby(level=0).value_counts().value_counts()).reset_index()
events_per_patient.columns = ["# of events","# of patients"]
events_per_patient
# Out:
#     # of events  # of patients
# 0             1         119351
# 1             3          19803
# 2             4          15521
# 3             2          15326
# 4             5          10053
# 5             6           3776
# 6             7           3100
# 7             8           2387
# 8            10           2269
# 9             9           2221
# 10           11           1676
# 11           12           1077
# 12           13            856
# 13           14            748
# 14           15            552
# 15           16            413
# 16           17            295
# 17           18            245
# 18           19            141
# 19           20             80
# 20           21             57
# 21           22             28
# 22           23             14
# 23           24              8
# 24           25              3

# %%
dataset.clinical_event_time.plot.hist(bins=[0,50,100,150,200,300,400,500,600])
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
tmp = dataset.groupby("clinical_event_member_id").clinical_event_id.value_counts().groupby(level=0).value_counts()
tmp = pd.DataFrame(tmp[tmp.values==1])
#tmp.columns = tmp.columns.get_level_values(0)
tmp = pd.DataFrame(tmp.unstack(-1).index)
tmp = dataset.merge(tmp)
tmp.clinical_event_time.plot.hist(bins=[0,50,100,150,300])
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
tmp = dataset.groupby("clinical_event_member_id").clinical_event_id.value_counts().groupby(level=0).value_counts()
tmp = pd.DataFrame(tmp[tmp.values==2])
#tmp.columns = tmp.columns.get_level_values(0)
tmp = pd.DataFrame(tmp.unstack(-1).index)
tmp = dataset.merge(tmp)
tmp.clinical_event_time.plot.hist(bins=[0,50,100,150,300])
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
dataset = dataset.sort_values(["clinical_event_member_id","clinical_event_time"])
dataset.clinical_event_time = pd.to_numeric(dataset.clinical_event_time)

# %%
dataset["consecutive_events"]=dataset.groupby("clinical_event_member_id").clinical_event_time.diff(1)

# %%
dataset.consecutive_events.plot.hist(bins=list(range(0,730,5)))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
dataset.consecutive_events.plot.hist(bins=list(range(0,730,45)))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
def get_member_interval_outcomes( data, hours_of_interest=[30,45]):
    df = data[['clinical_event_member_id','clinical_event_member_age','member_male','clinical_event_time']].drop_duplicates()
    psst = df.set_index('clinical_event_member_id')
    psst['tdindex'] = psst.apply(lambda x:np.arange(0,751,30,dtype=np.int),axis=1)
    psst=psst.explode('tdindex')
    psst['tdindex_feat']=psst['tdindex'].astype(np.int)
    psst=psst.reset_index().set_index(['clinical_event_member_id','tdindex'])
    psst["stroke_visit_180days"]=(psst['clinical_event_time'] > 0)&((psst['tdindex_feat'] + (180-1) >=psst['clinical_event_time']) & (psst['tdindex_feat'] < psst['clinical_event_time']))
    #psst = psst[((psst.clinical_event_time < 0) | ((psst.clinical_event_time>0) & (psst.clinical_event_time>psst.tdindex_feat)))]
    return psst

stroke_pats = dataset[dataset.clinical_event_name=="STROKE HOSPITALIZATION"][['clinical_event_member_id','clinical_event_time']]
tmp = dataset[['clinical_event_member_id','clinical_event_member_age','member_male']].merge(stroke_pats,how="left").fillna(-200)
psst = get_member_interval_outcomes(tmp)
# Out:
# <ipython-input-13-f59f494e6753>:4: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   psst['tdindex'] = psst.apply(lambda x:np.arange(0,751,30,dtype=np.int),axis=1)
# <ipython-input-13-f59f494e6753>:6: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   psst['tdindex_feat']=psst['tdindex'].astype(np.int)

# %%
psst
# Out:
#                                   clinical_event_member_age  member_male  \
# clinical_event_member_id tdindex
# 1                        0                               81            1
#                          30                              81            1
#                          60                              81            1
#                          90                              81            1
#                          120                             81            1
# ...                                                     ...          ...
# 200000                   630                             63            1
#                          660                             63            1
#                          690                             63            1
#                          720                             63            1
#                          750                             63            1
#
#                                   clinical_event_time  tdindex_feat  \
# clinical_event_member_id tdindex
# 1                        0                      641.0             0
#                          30                     641.0            30
#                          60                     641.0            60
#                          90                     641.0            90
#                          120                    641.0           120
# ...                                               ...           ...
# 200000                   630                   -200.0           630
#                          660                   -200.0           660
#                          690                   -200.0           690
#                          720                   -200.0           720
#                          750                   -200.0           750
#
#                                   stroke_visit_180days
# clinical_event_member_id tdindex
# 1                        0                       False
#                          30                      False
#                          60                      False
#                          90                      False
#                          120                     False
# ...                                                ...
# 200000                   630                     False
#                          660                     False
#                          690                     False
#                          720                     False
#                          750                     False
#
# [5200000 rows x 5 columns]

# %%
def multiIndex_pivot(df, index = None, columns = None, values = None):
    # https://github.com/pandas-dev/pandas/issues/23955
    output_df = df.copy(deep = True)
    if index is None:
        names = list(output_df.index.names)
        output_df = output_df.reset_index()
    else:
        names = index
    #print(output_df.info(verbose=True))
    output_df = output_df.assign(tuples_index = [tuple(i) for i in output_df[names].values])    
    #print(output_df.loc[output_df.duplicated(subset=['tuples_index'],keep=False),'tuples_index'].head(100))
    if isinstance(columns, list):
        output_df = output_df.assign(tuples_columns = [tuple(i) for i in output_df[columns].values])  # hashable
        output_df = output_df.pivot(index = 'tuples_index', columns = 'tuples_columns', values = values) 
        output_df.columns = pd.MultiIndex.from_tuples(output_df.columns, names = columns)  # reduced
    else:
        output_df = output_df.pivot(index = 'tuples_index', columns = columns, values = values)    
    output_df.index = pd.MultiIndex.from_tuples(output_df.index, names = names)
    return output_df


events = dataset[['clinical_event_member_id','clinical_event_name','clinical_event_time','clinical_event_id']]

cat_frames=[]
cat_frames.append(events.drop_duplicates(['clinical_event_member_id','clinical_event_time','clinical_event_name']))
cat_frames[-1]=cat_frames[-1].pipe(multiIndex_pivot, index = ['clinical_event_member_id','clinical_event_time'], columns = ['clinical_event_name'], values = 'clinical_event_time')

# create incidence (multi-hot) radiology feature
df_times=pd.concat(cat_frames,axis=1,ignore_index=True)
df_times.columns=[x for y in cat_frames for x in y.columns.get_level_values(0)]
df_times
# Out:
#                                               ANNUAL VISIT  \
# clinical_event_member_id clinical_event_time
# 1                        41                           41.0
#                          116                           NaN
#                          293                           NaN
#                          641                           NaN
# 2                        14                           14.0
# ...                                                    ...
# 199998                   321                           NaN
#                          451                           NaN
#                          541                           NaN
# 199999                   134                         134.0
# 200000                   127                         127.0
#
#                                               ATRIAL FIBRILLATION  \
# clinical_event_member_id clinical_event_time
# 1                        41                                   NaN
#                          116                                  NaN
#                          293                                  NaN
#                          641                                  NaN
# 2                        14                                   NaN
# ...                                                           ...
# 199998                   321                                  NaN
#                          451                                  NaN
#                          541                                  NaN
# 199999                   134                                  NaN
# 200000                   127                                  NaN
#
#                                               DIABETES MANAGEMENT VISIT  \
# clinical_event_member_id clinical_event_time
# 1                        41                                         NaN
#                          116                                        NaN
#                          293                                        NaN
#                          641                                        NaN
# 2                        14                                         NaN
# ...                                                                 ...
# 199998                   321                                        NaN
#                          451                                        NaN
#                          541                                        NaN
# 199999                   134                                        NaN
# 200000                   127                                        NaN
#
#                                               HEART FAILURE HOSPITALIZATION  \
# clinical_event_member_id clinical_event_time
# 1                        41                                             NaN
#                          116                                            NaN
#                          293                                            NaN
#                          641                                            NaN
# 2                        14                                             NaN
# ...                                                                     ...
# 199998                   321                                          321.0
#                          451                                            NaN
#                          541                                            NaN
# 199999                   134                                            NaN
# 200000                   127                                            NaN
#
#                                               HYPERTENSION MANAGEMENT VISIT  \
# clinical_event_member_id clinical_event_time
# 1                        41                                             NaN
#                          116                                          116.0
#                          293                                          293.0
#                          641                                            NaN
# 2                        14                                             NaN
# ...                                                                     ...
# 199998                   321                                            NaN
#                          451                                          451.0
#                          541                                            NaN
# 199999                   134                                            NaN
# 200000                   127                                            NaN
#
#                                               STROKE HOSPITALIZATION
# clinical_event_member_id clinical_event_time
# 1                        41                                      NaN
#                          116                                     NaN
#                          293                                     NaN
#                          641                                   641.0
# 2                        14                                      NaN
# ...                                                              ...
# 199998                   321                                     NaN
#                          451                                     NaN
#                          541                                   541.0
# 199999                   134                                     NaN
# 200000                   127                                     NaN
#
# [509735 rows x 6 columns]

# %%
df_hr=pd.concat(cat_frames,axis=1,ignore_index=True)


df_hr = df_hr.reset_index()
df_hr.clinical_event_time=np.ceil(df_hr.clinical_event_time/30.0)*30

d = {x:"last" for x in df_hr.columns}
df_hr = df_hr.groupby(['clinical_event_member_id','clinical_event_time'], as_index=True).aggregate(d).reindex(columns=df_hr.columns)
del df_hr['clinical_event_member_id'],df_hr['clinical_event_time']
df_hr

df_hr.columns=[x+'_lv' for y in cat_frames for x in y.columns.get_level_values(0)]


df_times_hr=df_hr.reindex(psst.index)
df_times_hr=df_times_hr.groupby('clinical_event_member_id').ffill().fillna(-10000-1).reset_index().set_index(['clinical_event_member_id','tdindex'])
df_times_hr=(-(df_times_hr.sub(df_times_hr.index.get_level_values(1),axis=0,level=1))).clip(upper=10000).astype(np.int)
df_times_hr=df_times_hr.replace(10000,-999)
df_times_hr
# Out:
# <ipython-input-16-1b42989eda2d>:17: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df_times_hr=(-(df_times_hr.sub(df_times_hr.index.get_level_values(1),axis=0,level=1))).clip(upper=10000).astype(np.int)
#                                   ANNUAL VISIT_lv  ATRIAL FIBRILLATION_lv  \
# clinical_event_member_id tdindex
# 1                        0                   -999                    -999
#                          30                  -999                    -999
#                          60                    19                    -999
#                          90                    49                    -999
#                          120                   79                    -999
# ...                                           ...                     ...
# 200000                   630                  503                    -999
#                          660                  533                    -999
#                          690                  563                    -999
#                          720                  593                    -999
#                          750                  623                    -999
#
#                                   DIABETES MANAGEMENT VISIT_lv  \
# clinical_event_member_id tdindex
# 1                        0                                -999
#                          30                               -999
#                          60                               -999
#                          90                               -999
#                          120                              -999
# ...                                                        ...
# 200000                   630                              -999
#                          660                              -999
#                          690                              -999
#                          720                              -999
#                          750                              -999
#
#                                   HEART FAILURE HOSPITALIZATION_lv  \
# clinical_event_member_id tdindex
# 1                        0                                    -999
#                          30                                   -999
#                          60                                   -999
#                          90                                   -999
#                          120                                  -999
# ...                                                            ...
# 200000                   630                                  -999
#                          660                                  -999
#                          690                                  -999
#                          720                                  -999
#                          750                                  -999
#
#                                   HYPERTENSION MANAGEMENT VISIT_lv  \
# clinical_event_member_id tdindex
# 1                        0                                    -999
#                          30                                   -999
#                          60                                   -999
#                          90                                   -999
#                          120                                     4
# ...                                                            ...
# 200000                   630                                  -999
#                          660                                  -999
#                          690                                  -999
#                          720                                  -999
#                          750                                  -999
#
#                                   STROKE HOSPITALIZATION_lv
# clinical_event_member_id tdindex
# 1                        0                             -999
#                          30                            -999
#                          60                            -999
#                          90                            -999
#                          120                           -999
# ...                                                     ...
# 200000                   630                           -999
#                          660                           -999
#                          690                           -999
#                          720                           -999
#                          750                           -999
#
# [5200000 rows x 6 columns]

# %%
df_hr
# Out:
#                                               ANNUAL VISIT_lv  \
# clinical_event_member_id clinical_event_time
# 1                        60.0                            41.0
#                          120.0                            NaN
#                          300.0                            NaN
#                          660.0                            NaN
# 2                        30.0                            14.0
# ...                                                       ...
# 199998                   330.0                            NaN
#                          480.0                            NaN
#                          570.0                            NaN
# 199999                   150.0                          134.0
# 200000                   150.0                          127.0
#
#                                               ATRIAL FIBRILLATION_lv  \
# clinical_event_member_id clinical_event_time
# 1                        60.0                                    NaN
#                          120.0                                   NaN
#                          300.0                                   NaN
#                          660.0                                   NaN
# 2                        30.0                                    NaN
# ...                                                              ...
# 199998                   330.0                                   NaN
#                          480.0                                   NaN
#                          570.0                                   NaN
# 199999                   150.0                                   NaN
# 200000                   150.0                                   NaN
#
#                                               DIABETES MANAGEMENT VISIT_lv  \
# clinical_event_member_id clinical_event_time
# 1                        60.0                                          NaN
#                          120.0                                         NaN
#                          300.0                                         NaN
#                          660.0                                         NaN
# 2                        30.0                                          NaN
# ...                                                                    ...
# 199998                   330.0                                         NaN
#                          480.0                                         NaN
#                          570.0                                         NaN
# 199999                   150.0                                         NaN
# 200000                   150.0                                         NaN
#
#                                               HEART FAILURE HOSPITALIZATION_lv  \
# clinical_event_member_id clinical_event_time
# 1                        60.0                                              NaN
#                          120.0                                             NaN
#                          300.0                                             NaN
#                          660.0                                             NaN
# 2                        30.0                                              NaN
# ...                                                                        ...
# 199998                   330.0                                           321.0
#                          480.0                                             NaN
#                          570.0                                             NaN
# 199999                   150.0                                             NaN
# 200000                   150.0                                             NaN
#
#                                               HYPERTENSION MANAGEMENT VISIT_lv  \
# clinical_event_member_id clinical_event_time
# 1                        60.0                                              NaN
#                          120.0                                           116.0
#                          300.0                                           293.0
#                          660.0                                             NaN
# 2                        30.0                                              NaN
# ...                                                                        ...
# 199998                   330.0                                           301.0
#                          480.0                                           451.0
#                          570.0                                             NaN
# 199999                   150.0                                             NaN
# 200000                   150.0                                             NaN
#
#                                               STROKE HOSPITALIZATION_lv
# clinical_event_member_id clinical_event_time
# 1                        60.0                                       NaN
#                          120.0                                      NaN
#                          300.0                                      NaN
#                          660.0                                    641.0
# 2                        30.0                                       NaN
# ...                                                                 ...
# 199998                   330.0                                      NaN
#                          480.0                                      NaN
#                          570.0                                    541.0
# 199999                   150.0                                      NaN
# 200000                   150.0                                      NaN
#
# [455989 rows x 6 columns]

# %%
df_hr=pd.concat(cat_frames,axis=1,ignore_index=True)


df_hr = df_hr.reset_index()
df_hr.clinical_event_time=np.ceil(df_hr.clinical_event_time/30.0)*30
df_hr=df_hr.set_index(['clinical_event_member_id','clinical_event_time'])
df_counts=df_hr.notnull().astype(np.int) 
df_counts=df_counts.groupby('clinical_event_member_id').cumsum().reset_index()

d = {x:"last" for x in df_counts.columns}
df_counts = df_counts.groupby(['clinical_event_member_id','clinical_event_time'], as_index=True).aggregate(d).reindex(columns=df_counts.columns)
del df_counts['clinical_event_member_id'],df_counts['clinical_event_time']
df_counts.columns=[x for y in cat_frames for x in y.columns.get_level_values(0)]

df_counts=df_counts.add_suffix('_cnt')
df_counts = df_counts.reindex(psst.index).ffill().fillna(0)
# Out:
# <ipython-input-18-42533913c4cc>:7: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df_counts=df_hr.notnull().astype(np.int)

# %%
df_counts
# Out:
#                                   ANNUAL VISIT_cnt  ATRIAL FIBRILLATION_cnt  \
# clinical_event_member_id tdindex
# 1                        0                     0.0                      0.0
#                          30                    0.0                      0.0
#                          60                    1.0                      0.0
#                          90                    1.0                      0.0
#                          120                   1.0                      0.0
# ...                                            ...                      ...
# 200000                   630                   1.0                      0.0
#                          660                   1.0                      0.0
#                          690                   1.0                      0.0
#                          720                   1.0                      0.0
#                          750                   1.0                      0.0
#
#                                   DIABETES MANAGEMENT VISIT_cnt  \
# clinical_event_member_id tdindex
# 1                        0                                  0.0
#                          30                                 0.0
#                          60                                 0.0
#                          90                                 0.0
#                          120                                0.0
# ...                                                         ...
# 200000                   630                                0.0
#                          660                                0.0
#                          690                                0.0
#                          720                                0.0
#                          750                                0.0
#
#                                   HEART FAILURE HOSPITALIZATION_cnt  \
# clinical_event_member_id tdindex
# 1                        0                                      0.0
#                          30                                     0.0
#                          60                                     0.0
#                          90                                     0.0
#                          120                                    0.0
# ...                                                             ...
# 200000                   630                                    0.0
#                          660                                    0.0
#                          690                                    0.0
#                          720                                    0.0
#                          750                                    0.0
#
#                                   HYPERTENSION MANAGEMENT VISIT_cnt  \
# clinical_event_member_id tdindex
# 1                        0                                      0.0
#                          30                                     0.0
#                          60                                     0.0
#                          90                                     0.0
#                          120                                    1.0
# ...                                                             ...
# 200000                   630                                    0.0
#                          660                                    0.0
#                          690                                    0.0
#                          720                                    0.0
#                          750                                    0.0
#
#                                   STROKE HOSPITALIZATION_cnt
# clinical_event_member_id tdindex
# 1                        0                               0.0
#                          30                              0.0
#                          60                              0.0
#                          90                              0.0
#                          120                             0.0
# ...                                                      ...
# 200000                   630                             0.0
#                          660                             0.0
#                          690                             0.0
#                          720                             0.0
#                          750                             0.0
#
# [5200000 rows x 6 columns]

# %%
df_rolling_counts = pd.concat([df_counts.groupby(level=0).diff(x).fillna(df_counts).add_suffix('_'+str(x*30)+'_daysago') for x in [1,2,3,4,5,6]],axis=1)

# %%
df_rolling_counts = pd.concat([psst,df_times_hr,df_counts,df_rolling_counts],axis=1)

# %%
df_rolling_counts.to_csv("feature_engineered_dataset.csv.gz")
# Out:
#                                   clinical_event_member_age  member_male  \
# clinical_event_member_id tdindex
# 1                        0                               81            1
#                          30                              81            1
#                          60                              81            1
#                          90                              81            1
#                          120                             81            1
# ...                                                     ...          ...
# 200000                   630                             63            1
#                          660                             63            1
#                          690                             63            1
#                          720                             63            1
#                          750                             63            1
#
#                                   clinical_event_time  tdindex_feat  \
# clinical_event_member_id tdindex
# 1                        0                      641.0             0
#                          30                     641.0            30
#                          60                     641.0            60
#                          90                     641.0            90
#                          120                    641.0           120
# ...                                               ...           ...
# 200000                   630                   -200.0           630
#                          660                   -200.0           660
#                          690                   -200.0           690
#                          720                   -200.0           720
#                          750                   -200.0           750
#
#                                   stroke_visit_180days  ANNUAL VISIT_lv  \
# clinical_event_member_id tdindex
# 1                        0                       False             -999
#                          30                      False             -999
#                          60                      False               19
#                          90                      False               49
#                          120                     False               79
# ...                                                ...              ...
# 200000                   630                     False              503
#                          660                     False              533
#                          690                     False              563
#                          720                     False              593
#                          750                     False              623
#
#                                   ATRIAL FIBRILLATION_lv  \
# clinical_event_member_id tdindex
# 1                        0                          -999
#                          30                         -999
#                          60                         -999
#                          90                         -999
#                          120                        -999
# ...                                                  ...
# 200000                   630                        -999
#                          660                        -999
#                          690                        -999
#                          720                        -999
#                          750                        -999
#
#                                   DIABETES MANAGEMENT VISIT_lv  \
# clinical_event_member_id tdindex
# 1                        0                                -999
#                          30                               -999
#                          60                               -999
#                          90                               -999
#                          120                              -999
# ...                                                        ...
# 200000                   630                              -999
#                          660                              -999
#                          690                              -999
#                          720                              -999
#                          750                              -999
#
#                                   HEART FAILURE HOSPITALIZATION_lv  \
# clinical_event_member_id tdindex
# 1                        0                                    -999
#                          30                                   -999
#                          60                                   -999
#                          90                                   -999
#                          120                                  -999
# ...                                                            ...
# 200000                   630                                  -999
#                          660                                  -999
#                          690                                  -999
#                          720                                  -999
#                          750                                  -999
#
#                                   HYPERTENSION MANAGEMENT VISIT_lv  ...  \
# clinical_event_member_id tdindex                                    ...
# 1                        0                                    -999  ...
#                          30                                   -999  ...
#                          60                                   -999  ...
#                          90                                   -999  ...
#                          120                                     4  ...
# ...                                                            ...  ...
# 200000                   630                                  -999  ...
#                          660                                  -999  ...
#                          690                                  -999  ...
#                          720                                  -999  ...
#                          750                                  -999  ...
#
#                                   DIABETES MANAGEMENT VISIT_cnt_150_daysago  \
# clinical_event_member_id tdindex
# 1                        0                                              0.0
#                          30                                             0.0
#                          60                                             0.0
#                          90                                             0.0
#                          120                                            0.0
# ...                                                                     ...
# 200000                   630                                            0.0
#                          660                                            0.0
#                          690                                            0.0
#                          720                                            0.0
#                          750                                            0.0
#
#                                   HEART FAILURE HOSPITALIZATION_cnt_150_daysago  \
# clinical_event_member_id tdindex
# 1                        0                                                  0.0
#                          30                                                 0.0
#                          60                                                 0.0
#                          90                                                 0.0
#                          120                                                0.0
# ...                                                                         ...
# 200000                   630                                                0.0
#                          660                                                0.0
#                          690                                                0.0
#                          720                                                0.0
#                          750                                                0.0
#
#                                   HYPERTENSION MANAGEMENT VISIT_cnt_150_daysago  \
# clinical_event_member_id tdindex
# 1                        0                                                  0.0
#                          30                                                 0.0
#                          60                                                 0.0
#                          90                                                 0.0
#                          120                                                1.0
# ...                                                                         ...
# 200000                   630                                                0.0
#                          660                                                0.0
#                          690                                                0.0
#                          720                                                0.0
#                          750                                                0.0
#
#                                   STROKE HOSPITALIZATION_cnt_150_daysago  \
# clinical_event_member_id tdindex
# 1                        0                                           0.0
#                          30                                          0.0
#                          60                                          0.0
#                          90                                          0.0
#                          120                                         0.0
# ...                                                                  ...
# 200000                   630                                         0.0
#                          660                                         0.0
#                          690                                         0.0
#                          720                                         0.0
#                          750                                         0.0
#
#                                   ANNUAL VISIT_cnt_180_daysago  \
# clinical_event_member_id tdindex
# 1                        0                                 0.0
#                          30                                0.0
#                          60                                1.0
#                          90                                1.0
#                          120                               1.0
# ...                                                        ...
# 200000                   630                               0.0
#                          660                               0.0
#                          690                               0.0
#                          720                               0.0
#                          750                               0.0
#
#                                   ATRIAL FIBRILLATION_cnt_180_daysago  \
# clinical_event_member_id tdindex
# 1                        0                                        0.0
#                          30                                       0.0
#                          60                                       0.0
#                          90                                       0.0
#                          120                                      0.0
# ...                                                               ...
# 200000                   630                                      0.0
#                          660                                      0.0
#                          690                                      0.0
#                          720                                      0.0
#                          750                                      0.0
#
#                                   DIABETES MANAGEMENT VISIT_cnt_180_daysago  \
# clinical_event_member_id tdindex
# 1                        0                                              0.0
#                          30                                             0.0
#                          60                                             0.0
#                          90                                             0.0
#                          120                                            0.0
# ...                                                                     ...
# 200000                   630                                            0.0
#                          660                                            0.0
#                          690                                            0.0
#                          720                                            0.0
#                          750                                            0.0
#
#                                   HEART FAILURE HOSPITALIZATION_cnt_180_daysago  \
# clinical_event_member_id tdindex
# 1                        0                                                  0.0
#                          30                                                 0.0
#                          60                                                 0.0
#                          90                                                 0.0
#                          120                                                0.0
# ...                                                                         ...
# 200000                   630                                                0.0
#                          660                                                0.0
#                          690                                                0.0
#                          720                                                0.0
#                          750                                                0.0
#
#                                   HYPERTENSION MANAGEMENT VISIT_cnt_180_daysago  \
# clinical_event_member_id tdindex
# 1                        0                                                  0.0
#                          30                                                 0.0
#                          60                                                 0.0
#                          90                                                 0.0
#                          120                                                1.0
# ...                                                                         ...
# 200000                   630                                                0.0
#                          660                                                0.0
#                          690                                                0.0
#                          720                                                0.0
#                          750                                                0.0
#
#                                   STROKE HOSPITALIZATION_cnt_180_daysago
# clinical_event_member_id tdindex
# 1                        0                                           0.0
#                          30                                          0.0
#                          60                                          0.0
#                          90                                          0.0
#                          120                                         0.0
# ...                                                                  ...
# 200000                   630                                         0.0
#                          660                                         0.0
#                          690                                         0.0
#                          720                                         0.0
#                          750                                         0.0
#
# [5200000 rows x 53 columns]

# %%
df_rolling_counts.to_csv("feature_engineered_dataset.csv")
